# %%
from predict import *
# %matplotlib inline
#predict(-122.4194, 37.7749, 5)
#predict(-122.4194, 37.7749, 12)

#predict(-123.5, 45.5, 5)
predict(-123.5, 45.5, 12)
# Out:
# ('very high', <Figure size 864x864 with 2 Axes>)
